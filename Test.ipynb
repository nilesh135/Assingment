# %%
import pandas as pd
from datetime import timedelta

def analyze_timecard(file_path):
    # Load the data from the Excel file
    df = pd.read_excel(file_path)

    # Convert relevant columns to datetime format
    df['Time'] = pd.to_datetime(df['Time'])
    df['Time Out'] = pd.to_datetime(df['Time Out'])
    df['Pay Cycle Start Date'] = pd.to_datetime(df['Pay Cycle Start Date'])
    df['Pay Cycle End Date'] = pd.to_datetime(df['Pay Cycle End Date'])

    # Sort the DataFrame by 'Employee Name' and 'Time'
    df.sort_values(by=['Employee Name', 'Time'], inplace=True)

    # Function to check consecutive days worked
    def consecutive_days(row):
        consecutive_days_count = 1
        prev_date = row['Time']
        
        for _, next_row in df[df['Employee Name'] == row['Employee Name']].iterrows():
            if (next_row['Time'] - prev_date).days == 1:
                consecutive_days_count += 1
                prev_date = next_row['Time']
            else:
                break
        
        return consecutive_days_count

    # Iterate over the records and print the required information
    for _, row in df.iterrows():
        consecutive_days_count = consecutive_days(row)
        
        if consecutive_days_count == 7:
            print(f"{row['Employee Name']} worked for 7 consecutive days, position: {row['Position ID']}, Pay Cycle Start Date: {row['Pay Cycle Start Date']}, Pay Scale End Date: {row['Pay Cycle End Date']}")
        
        # Check if there are previous records for the same employee
        previous_records = df[(df['Employee Name'] == row['Employee Name']) & (df['Time'] < row['Time'])]
        if not previous_records.empty:
            # Calculate time_between_shifts
            time_between_shifts = (row['Time'] - previous_records.iloc[-1]['Time']).seconds / 3600
            
            if 1 < time_between_shifts < 10:
                print(f"{row['Employee Name']} has less than 10 hours between shifts but greater than 1 hour, position: {row['Position ID']}, Pay Cycle Start Date: {row['Pay Cycle Start Date']}, Pay Scale End Date: {row['Pay Cycle End Date']}")
        
        # Convert 'Timecard Hours (as Time)' to timedelta
        timecard_hours_str = str(row['Timecard Hours (as Time)'])
        try:
            if ':' in timecard_hours_str:
                hours, minutes = map(int, timecard_hours_str.split(':'))
                timecard_hours = timedelta(hours=hours, minutes=minutes)
                
                if timecard_hours.total_seconds() / 3600 > 14:
                    print(f"{row['Employee Name']} worked for more than 14 hours in a single shift, position: {row['Position ID']}, Pay Cycle Start Date: {row['Pay Cycle Start Date']}, Pay Scale End Date: {row['Pay Cycle End Date']}")
            else:
                print(f"Skipping row due to unexpected 'Timecard Hours (as Time)' format: {timecard_hours_str}")
        except (ValueError, TypeError):
            # Handle cases where the format is unexpected or cannot be converted to timedelta
            print(f"Skipping row due to unexpected 'Timecard Hours (as Time)' format: {timecard_hours_str}")

if __name__ == "__main__":
    # Specify the path to your Excel file
    file_path = 'F:/Assingment/Assignment_Timecard.XLSX'

    # Run the analysis
    analyze_timecard(file_path)
# Out:
# AGeX, WaMhaW REGerM PeWa has less than 10 hours between shifts but greater than 1 hour, position: WFS000588, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# AGeX, WaMhaW REGerM PeWa has less than 10 hours between shifts but greater than 1 hour, position: WFS000588, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# AGeX, WaMhaW REGerM PeWa has less than 10 hours between shifts but greater than 1 hour, position: WFS000588, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# AGeX, WaMhaW REGerM PeWa has less than 10 hours between shifts but greater than 1 hour, position: WFS000588, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# AGeX, WaMhaW REGerM PeWa has less than 10 hours between shifts but greater than 1 hour, position: WFS000588, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# AXcEcer, ECar JesAs has less than 10 hours between shifts but greater than 1 hour, position: WFS000541, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# AXcEcer, ECar JesAs has less than 10 hours between shifts but greater than 1 hour, position: WFS000541, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# AXcEcer, ECar JesAs has less than 10 hours between shifts but greater than 1 hour, position: WFS000541, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# AXcEcer, ECar JesAs has less than 10 hours between shifts but greater than 1 hour, position: WFS000541, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# AXcEcer, ECar JesAs has less than 10 hours between shifts but greater than 1 hour, position: WFS000541, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# AXcEcer, ECar JesAs has less than 10 hours between shifts but greater than 1 hour, position: WFS000541, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# AXcEcer, ECar JesAs has less than 10 hours between shifts but greater than 1 hour, position: WFS000541, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# AXvarez, Edgar has less than 10 hours between shifts but greater than 1 hour, position: WFS000457, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# AXvarez, Edgar has less than 10 hours between shifts but greater than 1 hour, position: WFS000457, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# AXvarez, Edgar has less than 10 hours between shifts but greater than 1 hour, position: WFS000457, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# AXvarez, Edgar has less than 10 hours between shifts but greater than 1 hour, position: WFS000457, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# AXvarez, Edgar has less than 10 hours between shifts but greater than 1 hour, position: WFS000457, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# AXvarez, Edgar has less than 10 hours between shifts but greater than 1 hour, position: WFS000457, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# AXvarez, Edgar has less than 10 hours between shifts but greater than 1 hour, position: WFS000457, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# AXvarez, Edgar has less than 10 hours between shifts but greater than 1 hour, position: WFS000457, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# AXvarez, Edgar has less than 10 hours between shifts but greater than 1 hour, position: WFS000457, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# AXvarez, Edgar has less than 10 hours between shifts but greater than 1 hour, position: WFS000457, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# ArCeWMa FXEres, JEWaMhaW has less than 10 hours between shifts but greater than 1 hour, position: WFS000584, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# ArCeWMa FXEres, JEWaMhaW has less than 10 hours between shifts but greater than 1 hour, position: WFS000584, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# ArCeWMa FXEres, JEWaMhaW has less than 10 hours between shifts but greater than 1 hour, position: WFS000584, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# ArCeWMa FXEres, JEWaMhaW has less than 10 hours between shifts but greater than 1 hour, position: WFS000584, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# ArCeWMa FXEres, JEWaMhaW has less than 10 hours between shifts but greater than 1 hour, position: WFS000584, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# ArCeWMa FXEres, JEWaMhaW has less than 10 hours between shifts but greater than 1 hour, position: WFS000584, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# ArCeWMa FXEres, JEWaMhaW has less than 10 hours between shifts but greater than 1 hour, position: WFS000584, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# ArCeWMa FXEres, JEWaMhaW has less than 10 hours between shifts but greater than 1 hour, position: WFS000584, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# ArCeWMa FXEres, JEWaMhaW has less than 10 hours between shifts but greater than 1 hour, position: WFS000584, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# ArEsMigAi, AXexaWder has less than 10 hours between shifts but greater than 1 hour, position: WFS000306, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# ArEsMigAi, AXexaWder has less than 10 hours between shifts but greater than 1 hour, position: WFS000306, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# ArEsMigAi, AXexaWder has less than 10 hours between shifts but greater than 1 hour, position: WFS000306, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# ArEsMigAi, AXexaWder has less than 10 hours between shifts but greater than 1 hour, position: WFS000306, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# ArEsMigAi, AXexaWder has less than 10 hours between shifts but greater than 1 hour, position: WFS000306, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# ArEsMigAi, AXexaWder has less than 10 hours between shifts but greater than 1 hour, position: WFS000306, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# ArEsMigAi, AXexaWder has less than 10 hours between shifts but greater than 1 hour, position: WFS000306, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# ArevaXE, JEse has less than 10 hours between shifts but greater than 1 hour, position: WFS000491, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# ArevaXE, JEse has less than 10 hours between shifts but greater than 1 hour, position: WFS000491, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# ArevaXE, JEse has less than 10 hours between shifts but greater than 1 hour, position: WFS000491, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# ArevaXE, JEse has less than 10 hours between shifts but greater than 1 hour, position: WFS000491, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# ArevaXE, JEse has less than 10 hours between shifts but greater than 1 hour, position: WFS000491, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# ArevaXE, JEse has less than 10 hours between shifts but greater than 1 hour, position: WFS000491, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# ArevaXE, JEse has less than 10 hours between shifts but greater than 1 hour, position: WFS000491, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# ArevaXE, JEse has less than 10 hours between shifts but greater than 1 hour, position: WFS000491, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# ArevaXE, JEse has less than 10 hours between shifts but greater than 1 hour, position: WFS000491, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# Arias, FeXipe has less than 10 hours between shifts but greater than 1 hour, position: WFS000170, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# Arias, FeXipe has less than 10 hours between shifts but greater than 1 hour, position: WFS000170, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# Arias, FeXipe has less than 10 hours between shifts but greater than 1 hour, position: WFS000170, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# Arias, FeXipe has less than 10 hours between shifts but greater than 1 hour, position: WFS000170, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# Arias, FeXipe has less than 10 hours between shifts but greater than 1 hour, position: WFS000170, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# Arias, FeXipe has less than 10 hours between shifts but greater than 1 hour, position: WFS000170, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# Arias, FeXipe has less than 10 hours between shifts but greater than 1 hour, position: WFS000170, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# Arias, FeXipe has less than 10 hours between shifts but greater than 1 hour, position: WFS000170, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# Arias, FeXipe has less than 10 hours between shifts but greater than 1 hour, position: WFS000170, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# ArrAMia, AXexis ArMArE has less than 10 hours between shifts but greater than 1 hour, position: WFS000518, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# ArrAMia, AXexis ArMArE has less than 10 hours between shifts but greater than 1 hour, position: WFS000518, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# ArrAMia, AXexis ArMArE has less than 10 hours between shifts but greater than 1 hour, position: WFS000518, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# ArrAMia, AXexis ArMArE has less than 10 hours between shifts but greater than 1 hour, position: WFS000518, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# Skipping row due to unexpected 'Timecard Hours (as Time)' format: nan
# CAevas ZavaXa, JErge XAis has less than 10 hours between shifts but greater than 1 hour, position: WFS000571, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# CAevas ZavaXa, JErge XAis has less than 10 hours between shifts but greater than 1 hour, position: WFS000571, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# CAevas ZavaXa, JErge XAis has less than 10 hours between shifts but greater than 1 hour, position: WFS000571, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# CAevas ZavaXa, JErge XAis has less than 10 hours between shifts but greater than 1 hour, position: WFS000571, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# CAevas ZavaXa, JErge XAis has less than 10 hours between shifts but greater than 1 hour, position: WFS000571, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# CAevas ZavaXa, JErge XAis has less than 10 hours between shifts but greater than 1 hour, position: WFS000571, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# CAevas ZavaXa, JErge XAis has less than 10 hours between shifts but greater than 1 hour, position: WFS000571, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# CAevas ZavaXa, JErge XAis has less than 10 hours between shifts but greater than 1 hour, position: WFS000571, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# CAevas ZavaXa, JErge XAis has less than 10 hours between shifts but greater than 1 hour, position: WFS000571, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# CEMMa, Jessica has less than 10 hours between shifts but greater than 1 hour, position: WFS000503, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# CEMMa, Jessica has less than 10 hours between shifts but greater than 1 hour, position: WFS000503, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# CEMMa, Jessica has less than 10 hours between shifts but greater than 1 hour, position: WFS000503, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# CEMMa, Jessica has less than 10 hours between shifts but greater than 1 hour, position: WFS000503, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# CEMMa, Jessica has less than 10 hours between shifts but greater than 1 hour, position: WFS000503, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# CEMMa, Jessica has less than 10 hours between shifts but greater than 1 hour, position: WFS000503, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# CEMMa, Jessica has less than 10 hours between shifts but greater than 1 hour, position: WFS000503, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# CEMMa, Jessica has less than 10 hours between shifts but greater than 1 hour, position: WFS000503, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# CEMMa, Jessica has less than 10 hours between shifts but greater than 1 hour, position: WFS000503, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# CEMMa, Jessica has less than 10 hours between shifts but greater than 1 hour, position: WFS000503, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# CErMes, DEAgXas Farid has less than 10 hours between shifts but greater than 1 hour, position: WFS000495, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# CErMes, DEAgXas Farid has less than 10 hours between shifts but greater than 1 hour, position: WFS000495, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# CErMes, DEAgXas Farid has less than 10 hours between shifts but greater than 1 hour, position: WFS000495, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# CErMes, DEAgXas Farid has less than 10 hours between shifts but greater than 1 hour, position: WFS000495, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# CErMes, DEAgXas Farid has less than 10 hours between shifts but greater than 1 hour, position: WFS000495, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# CErMes, DEAgXas Farid has less than 10 hours between shifts but greater than 1 hour, position: WFS000495, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# CErMes, DEAgXas Farid has less than 10 hours between shifts but greater than 1 hour, position: WFS000495, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# CErMes, DEAgXas Farid has less than 10 hours between shifts but greater than 1 hour, position: WFS000495, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# CErMes, DEAgXas Farid has less than 10 hours between shifts but greater than 1 hour, position: WFS000495, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# CErMes, DEAgXas Farid has less than 10 hours between shifts but greater than 1 hour, position: WFS000495, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# CEreira Jr, JEse has less than 10 hours between shifts but greater than 1 hour, position: WFS000456, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# CEreira Jr, JEse has less than 10 hours between shifts but greater than 1 hour, position: WFS000456, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# CEreira Jr, JEse has less than 10 hours between shifts but greater than 1 hour, position: WFS000456, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# CEreira Jr, JEse has less than 10 hours between shifts but greater than 1 hour, position: WFS000456, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# CEreira Jr, JEse has less than 10 hours between shifts but greater than 1 hour, position: WFS000456, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# CEreira Jr, JEse has less than 10 hours between shifts but greater than 1 hour, position: WFS000456, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# CEreira Jr, JEse has less than 10 hours between shifts but greater than 1 hour, position: WFS000456, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# CEreira Jr, JEse has less than 10 hours between shifts but greater than 1 hour, position: WFS000456, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# CEreira Jr, JEse has less than 10 hours between shifts but greater than 1 hour, position: WFS000456, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# CaMXEck, CEhaCCed has less than 10 hours between shifts but greater than 1 hour, position: WFS000362, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# CaMXEck, CEhaCCed has less than 10 hours between shifts but greater than 1 hour, position: WFS000362, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# CaMXEck, CEhaCCed has less than 10 hours between shifts but greater than 1 hour, position: WFS000362, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# CaMXEck, CEhaCCed has less than 10 hours between shifts but greater than 1 hour, position: WFS000362, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# CaMXEck, CEhaCCed has less than 10 hours between shifts but greater than 1 hour, position: WFS000362, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# CaMXEck, CEhaCCed has less than 10 hours between shifts but greater than 1 hour, position: WFS000362, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# CaMXEck, CEhaCCed has less than 10 hours between shifts but greater than 1 hour, position: WFS000362, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# CaMXEck, CEhaCCed has less than 10 hours between shifts but greater than 1 hour, position: WFS000362, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# CaMaXaWE, CeghaW has less than 10 hours between shifts but greater than 1 hour, position: WFS000153, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# CaMaXaWE, CeghaW has less than 10 hours between shifts but greater than 1 hour, position: WFS000153, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# CaMaXaWE, CeghaW has less than 10 hours between shifts but greater than 1 hour, position: WFS000153, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# CaMaXaWE, CeghaW has less than 10 hours between shifts but greater than 1 hour, position: WFS000153, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# CaMaXaWE, CeghaW has less than 10 hours between shifts but greater than 1 hour, position: WFS000153, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# CaMaXaWE, CeghaW has less than 10 hours between shifts but greater than 1 hour, position: WFS000153, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# CaMaXaWE, CeghaW has less than 10 hours between shifts but greater than 1 hour, position: WFS000153, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# CaMaXaWE, CeghaW has less than 10 hours between shifts but greater than 1 hour, position: WFS000153, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# CaMaXaWE, CeghaW has less than 10 hours between shifts but greater than 1 hour, position: WFS000153, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# CaXdEWadE, AXfEWsE has less than 10 hours between shifts but greater than 1 hour, position: WFS000463, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# CaXdEWadE, AXfEWsE has less than 10 hours between shifts but greater than 1 hour, position: WFS000463, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# CaXdEWadE, AXfEWsE has less than 10 hours between shifts but greater than 1 hour, position: WFS000463, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# CaXdEWadE, AXfEWsE has less than 10 hours between shifts but greater than 1 hour, position: WFS000463, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# CaXdEWadE, AXfEWsE has less than 10 hours between shifts but greater than 1 hour, position: WFS000463, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# CaXdEWadE, AXfEWsE has less than 10 hours between shifts but greater than 1 hour, position: WFS000463, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# CaXdEWadE, AXfEWsE has less than 10 hours between shifts but greater than 1 hour, position: WFS000463, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# CaXdEWadE, AXfEWsE has less than 10 hours between shifts but greater than 1 hour, position: WFS000463, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# CaXdEWadE, AXfEWsE has less than 10 hours between shifts but greater than 1 hour, position: WFS000463, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# CaXdEWadE, AXfEWsE has less than 10 hours between shifts but greater than 1 hour, position: WFS000463, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# CarMer, XyWWeXX DejAaW Jr has less than 10 hours between shifts but greater than 1 hour, position: WFS000576, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# CaraGiXXa, AWMhEWy has less than 10 hours between shifts but greater than 1 hour, position: WFS000514, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# CaraGiXXa, AWMhEWy has less than 10 hours between shifts but greater than 1 hour, position: WFS000514, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# CaraGiXXa, AWMhEWy has less than 10 hours between shifts but greater than 1 hour, position: WFS000514, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# Caxies, MerreXX has less than 10 hours between shifts but greater than 1 hour, position: WFS000500, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# Caxies, MerreXX has less than 10 hours between shifts but greater than 1 hour, position: WFS000500, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# Caxies, MerreXX has less than 10 hours between shifts but greater than 1 hour, position: WFS000500, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# Caxies, MerreXX has less than 10 hours between shifts but greater than 1 hour, position: WFS000500, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# Caxies, MerreXX has less than 10 hours between shifts but greater than 1 hour, position: WFS000500, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# Caxies, MerreXX has less than 10 hours between shifts but greater than 1 hour, position: WFS000500, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# Caxies, MerreXX has less than 10 hours between shifts but greater than 1 hour, position: WFS000500, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# Caxies, MerreXX has less than 10 hours between shifts but greater than 1 hour, position: WFS000500, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# Caxies, MerreXX has less than 10 hours between shifts but greater than 1 hour, position: WFS000500, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# CcRAWWeX, REWaXd Xee has less than 10 hours between shifts but greater than 1 hour, position: WFS000501, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# CcRAWWeX, REWaXd Xee has less than 10 hours between shifts but greater than 1 hour, position: WFS000501, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# CcRAWWeX, REWaXd Xee has less than 10 hours between shifts but greater than 1 hour, position: WFS000501, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# CcRAWWeX, REWaXd Xee has less than 10 hours between shifts but greater than 1 hour, position: WFS000501, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# CcRAWWeX, REWaXd Xee has less than 10 hours between shifts but greater than 1 hour, position: WFS000501, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# CcRAWWeX, REWaXd Xee has less than 10 hours between shifts but greater than 1 hour, position: WFS000501, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# CcRAWWeX, REWaXd Xee has less than 10 hours between shifts but greater than 1 hour, position: WFS000501, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# CcRAWWeX, REWaXd Xee has less than 10 hours between shifts but greater than 1 hour, position: WFS000501, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# CeWdEza, Erik has less than 10 hours between shifts but greater than 1 hour, position: WFS000465, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# CeWdEza, Erik has less than 10 hours between shifts but greater than 1 hour, position: WFS000465, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# CeWdEza, Erik has less than 10 hours between shifts but greater than 1 hour, position: WFS000465, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# CeciWa, SiXvesMre Jr has less than 10 hours between shifts but greater than 1 hour, position: WFS000528, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# CeciWa, SiXvesMre Jr has less than 10 hours between shifts but greater than 1 hour, position: WFS000528, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# CeciWa, SiXvesMre Jr has less than 10 hours between shifts but greater than 1 hour, position: WFS000528, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# CeciWa, SiXvesMre Jr has less than 10 hours between shifts but greater than 1 hour, position: WFS000528, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# CeciWa, SiXvesMre Jr has less than 10 hours between shifts but greater than 1 hour, position: WFS000528, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# CercadE, CrisMiaW has less than 10 hours between shifts but greater than 1 hour, position: WFS000496, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# CercadE, CrisMiaW has less than 10 hours between shifts but greater than 1 hour, position: WFS000496, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# CercadE, CrisMiaW has less than 10 hours between shifts but greater than 1 hour, position: WFS000496, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# CercadE, CrisMiaW has less than 10 hours between shifts but greater than 1 hour, position: WFS000496, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# CercadE, CrisMiaW has less than 10 hours between shifts but greater than 1 hour, position: WFS000496, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# CercadE, CrisMiaW has less than 10 hours between shifts but greater than 1 hour, position: WFS000496, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# CercadE, CrisMiaW has less than 10 hours between shifts but greater than 1 hour, position: WFS000496, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# CercadE, CrisMiaW has less than 10 hours between shifts but greater than 1 hour, position: WFS000496, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# CercadE, SaAX has less than 10 hours between shifts but greater than 1 hour, position: WFS000446, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# CercadE, SaAX has less than 10 hours between shifts but greater than 1 hour, position: WFS000446, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# CercadE, SaAX has less than 10 hours between shifts but greater than 1 hour, position: WFS000446, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# CercadE, SaAX has less than 10 hours between shifts but greater than 1 hour, position: WFS000446, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# CercadE, SaAX has less than 10 hours between shifts but greater than 1 hour, position: WFS000446, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# CercadE, SaAX has less than 10 hours between shifts but greater than 1 hour, position: WFS000446, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# CercadE, SaAX has less than 10 hours between shifts but greater than 1 hour, position: WFS000446, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# CercadE, SaAX has less than 10 hours between shifts but greater than 1 hour, position: WFS000446, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# CercadE, SaAX has less than 10 hours between shifts but greater than 1 hour, position: WFS000446, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# CesiWa CEreWE, KeviW FaGiaW has less than 10 hours between shifts but greater than 1 hour, position: WFS000548, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# CesiWa CEreWE, KeviW FaGiaW has less than 10 hours between shifts but greater than 1 hour, position: WFS000548, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# CesiWa CEreWE, KeviW FaGiaW has less than 10 hours between shifts but greater than 1 hour, position: WFS000548, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# CesiWa CEreWE, KeviW FaGiaW has less than 10 hours between shifts but greater than 1 hour, position: WFS000548, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# CesiWa CEreWE, KeviW FaGiaW has less than 10 hours between shifts but greater than 1 hour, position: WFS000548, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# CesiWa CEreWE, KeviW FaGiaW has less than 10 hours between shifts but greater than 1 hour, position: WFS000548, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# CesiWa CEreWE, KeviW FaGiaW has less than 10 hours between shifts but greater than 1 hour, position: WFS000548, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# ChaCErE, HEXger CarMiWez has less than 10 hours between shifts but greater than 1 hour, position: WFS000509, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# ChaCErE, HEXger CarMiWez has less than 10 hours between shifts but greater than 1 hour, position: WFS000509, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# ChaCErE, HEXger CarMiWez has less than 10 hours between shifts but greater than 1 hour, position: WFS000509, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# ChaCErE, HEXger CarMiWez has less than 10 hours between shifts but greater than 1 hour, position: WFS000509, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# ChaCErE, HEXger CarMiWez has less than 10 hours between shifts but greater than 1 hour, position: WFS000509, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# ChaCErE, HEXger CarMiWez has less than 10 hours between shifts but greater than 1 hour, position: WFS000509, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# ChaCErE, HEXger CarMiWez has less than 10 hours between shifts but greater than 1 hour, position: WFS000509, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# ChaCErE, HEXger CarMiWez has less than 10 hours between shifts but greater than 1 hour, position: WFS000509, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# ChaCErE, HEXger CarMiWez has less than 10 hours between shifts but greater than 1 hour, position: WFS000509, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# CharXes, EGadiah SEraccE Jr has less than 10 hours between shifts but greater than 1 hour, position: WFS000566, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# CharXes, EGadiah SEraccE Jr has less than 10 hours between shifts but greater than 1 hour, position: WFS000566, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# CharXes, EGadiah SEraccE Jr has less than 10 hours between shifts but greater than 1 hour, position: WFS000566, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# CiGriaW DeXgadE, EXeWa S has less than 10 hours between shifts but greater than 1 hour, position: WFS000574, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# CiGriaW DeXgadE, EXeWa S has less than 10 hours between shifts but greater than 1 hour, position: WFS000574, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# CiGriaW DeXgadE, EXeWa S has less than 10 hours between shifts but greater than 1 hour, position: WFS000574, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# CiGriaW DeXgadE, EXeWa S has less than 10 hours between shifts but greater than 1 hour, position: WFS000574, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# DECiWgAez AviWa, CigAeX AWgeX has less than 10 hours between shifts but greater than 1 hour, position: WFS000569, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# DECiWgAez AviWa, CigAeX AWgeX has less than 10 hours between shifts but greater than 1 hour, position: WFS000569, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# DECiWgAez AviWa, CigAeX AWgeX has less than 10 hours between shifts but greater than 1 hour, position: WFS000569, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# DECiWgAez AviWa, CigAeX AWgeX has less than 10 hours between shifts but greater than 1 hour, position: WFS000569, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# DECiWgAez AviWa, CigAeX AWgeX has less than 10 hours between shifts but greater than 1 hour, position: WFS000569, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# DECiWgAez AviWa, CigAeX AWgeX has less than 10 hours between shifts but greater than 1 hour, position: WFS000569, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# DECiWgAez AviWa, CigAeX AWgeX has less than 10 hours between shifts but greater than 1 hour, position: WFS000569, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# De XEs SaWMEs, JEseph XAis has less than 10 hours between shifts but greater than 1 hour, position: WFS000582, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# De XEs SaWMEs, JEseph XAis has less than 10 hours between shifts but greater than 1 hour, position: WFS000582, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# De XEs SaWMEs, JEseph XAis has less than 10 hours between shifts but greater than 1 hour, position: WFS000582, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# De XEs SaWMEs, JEseph XAis has less than 10 hours between shifts but greater than 1 hour, position: WFS000582, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# De XEs SaWMEs, JEseph XAis has less than 10 hours between shifts but greater than 1 hour, position: WFS000582, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# De XEs SaWMEs, JEseph XAis has less than 10 hours between shifts but greater than 1 hour, position: WFS000582, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# De Xa Cerda, IgWaciE has less than 10 hours between shifts but greater than 1 hour, position: WFS000318, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# De Xa Cerda, IgWaciE has less than 10 hours between shifts but greater than 1 hour, position: WFS000318, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# De Xa Cerda, IgWaciE has less than 10 hours between shifts but greater than 1 hour, position: WFS000318, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# De Xa Cerda, IgWaciE has less than 10 hours between shifts but greater than 1 hour, position: WFS000318, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# De Xa Cerda, IgWaciE has less than 10 hours between shifts but greater than 1 hour, position: WFS000318, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# De Xa Cerda, IgWaciE has less than 10 hours between shifts but greater than 1 hour, position: WFS000318, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# De Xa Cerda, IgWaciE has less than 10 hours between shifts but greater than 1 hour, position: WFS000318, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# De Xa Cerda, IgWaciE has less than 10 hours between shifts but greater than 1 hour, position: WFS000318, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# De Xa Cerda, IgWaciE has less than 10 hours between shifts but greater than 1 hour, position: WFS000318, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# DeXgadiXXE REdarMe, ChrisMiaW S has less than 10 hours between shifts but greater than 1 hour, position: WFS000523, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# DeXgadiXXE REdarMe, ChrisMiaW S has less than 10 hours between shifts but greater than 1 hour, position: WFS000523, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# DeXgadiXXE REdarMe, ChrisMiaW S has less than 10 hours between shifts but greater than 1 hour, position: WFS000523, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# DeXgadiXXE REdarMe, ChrisMiaW S has less than 10 hours between shifts but greater than 1 hour, position: WFS000523, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# DeXgadiXXE REdarMe, ChrisMiaW S has less than 10 hours between shifts but greater than 1 hour, position: WFS000523, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# DeXgadiXXE REdarMe, ChrisMiaW S worked for more than 14 hours in a single shift, position: WFS000523, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# DeXgadiXXE REdarMe, ChrisMiaW S has less than 10 hours between shifts but greater than 1 hour, position: WFS000523, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# DeXgadiXXE REdarMe, ChrisMiaW S has less than 10 hours between shifts but greater than 1 hour, position: WFS000523, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# DeXgadiXXE REdarMe, ChrisMiaW S has less than 10 hours between shifts but greater than 1 hour, position: WFS000523, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# DeXgadiXXE REdarMe, ChrisMiaW S has less than 10 hours between shifts but greater than 1 hour, position: WFS000523, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# DiWh, DaA has less than 10 hours between shifts but greater than 1 hour, position: WFS000268, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# DiWh, DaA has less than 10 hours between shifts but greater than 1 hour, position: WFS000268, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# DiWh, DaA has less than 10 hours between shifts but greater than 1 hour, position: WFS000268, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# DiWh, DaA has less than 10 hours between shifts but greater than 1 hour, position: WFS000268, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# DiWh, DaA has less than 10 hours between shifts but greater than 1 hour, position: WFS000268, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# DiWh, DaA has less than 10 hours between shifts but greater than 1 hour, position: WFS000268, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# DiWh, DaA has less than 10 hours between shifts but greater than 1 hour, position: WFS000268, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# DiWh, DaA has less than 10 hours between shifts but greater than 1 hour, position: WFS000268, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# DiXXard, JEwaWW Cedric has less than 10 hours between shifts but greater than 1 hour, position: WFS000519, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# DiXXard, JEwaWW Cedric has less than 10 hours between shifts but greater than 1 hour, position: WFS000519, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# DiXXard, JEwaWW Cedric has less than 10 hours between shifts but greater than 1 hour, position: WFS000519, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# DiXXard, JEwaWW Cedric has less than 10 hours between shifts but greater than 1 hour, position: WFS000519, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# DiXXard, JEwaWW Cedric has less than 10 hours between shifts but greater than 1 hour, position: WFS000519, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# DiXXard, JEwaWW Cedric has less than 10 hours between shifts but greater than 1 hour, position: WFS000519, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# DiXXard, JEwaWW Cedric has less than 10 hours between shifts but greater than 1 hour, position: WFS000519, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# DiXXard, JEwaWW Cedric has less than 10 hours between shifts but greater than 1 hour, position: WFS000519, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# DiXXard, JEwaWW Cedric has less than 10 hours between shifts but greater than 1 hour, position: WFS000519, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# DiXXard, JEwaWW Cedric has less than 10 hours between shifts but greater than 1 hour, position: WFS000519, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# Diaz GaXvez, RicardE JEsAe has less than 10 hours between shifts but greater than 1 hour, position: WFS000551, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# Diaz GaXvez, RicardE JEsAe has less than 10 hours between shifts but greater than 1 hour, position: WFS000551, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# Diaz GaXvez, RicardE JEsAe has less than 10 hours between shifts but greater than 1 hour, position: WFS000551, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# Diaz GaXvez, RicardE JEsAe has less than 10 hours between shifts but greater than 1 hour, position: WFS000551, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# Diaz GaXvez, RicardE JEsAe has less than 10 hours between shifts but greater than 1 hour, position: WFS000551, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# Diaz GaXvez, RicardE JEsAe has less than 10 hours between shifts but greater than 1 hour, position: WFS000551, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# Diaz GaXvez, RicardE JEsAe has less than 10 hours between shifts but greater than 1 hour, position: WFS000551, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# Diaz GaXvez, RicardE JEsAe has less than 10 hours between shifts but greater than 1 hour, position: WFS000551, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# Diaz GaXvez, RicardE JEsAe has less than 10 hours between shifts but greater than 1 hour, position: WFS000551, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# EXivares, FeXCaW has less than 10 hours between shifts but greater than 1 hour, position: WFS000508, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# EXivares, FeXCaW has less than 10 hours between shifts but greater than 1 hour, position: WFS000508, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# ...
# VasqAez, AXfredE has less than 10 hours between shifts but greater than 1 hour, position: WFS000391, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# VasqAez, JEhW SeGasMiaW has less than 10 hours between shifts but greater than 1 hour, position: WFS000578, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# VasqAez, JEhW SeGasMiaW has less than 10 hours between shifts but greater than 1 hour, position: WFS000578, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# VasqAez, JEhW SeGasMiaW has less than 10 hours between shifts but greater than 1 hour, position: WFS000578, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# VasqAez, JEhW SeGasMiaW has less than 10 hours between shifts but greater than 1 hour, position: WFS000578, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# VasqAez, JEhW SeGasMiaW has less than 10 hours between shifts but greater than 1 hour, position: WFS000578, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# ViXXa, AXfredE AieXXE has less than 10 hours between shifts but greater than 1 hour, position: WFS000583, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# ViXXa, AXfredE AieXXE has less than 10 hours between shifts but greater than 1 hour, position: WFS000583, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# ViXXa, AXfredE AieXXE has less than 10 hours between shifts but greater than 1 hour, position: WFS000583, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# ViXXa, AXfredE AieXXE has less than 10 hours between shifts but greater than 1 hour, position: WFS000583, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# ViXXa, AXfredE AieXXE has less than 10 hours between shifts but greater than 1 hour, position: WFS000583, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# Skipping row due to unexpected 'Timecard Hours (as Time)' format: nan
# WgAyeW, RayCEWd has less than 10 hours between shifts but greater than 1 hour, position: WFS000589, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# WgAyeW, RayCEWd has less than 10 hours between shifts but greater than 1 hour, position: WFS000589, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# WgAyeW, RayCEWd has less than 10 hours between shifts but greater than 1 hour, position: WFS000589, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# WgAyeW, RayCEWd has less than 10 hours between shifts but greater than 1 hour, position: WFS000589, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# WgAyeW, RayCEWd has less than 10 hours between shifts but greater than 1 hour, position: WFS000589, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# Skipping row due to unexpected 'Timecard Hours (as Time)' format: nan
# WiXXiaCs, MyrreXX has less than 10 hours between shifts but greater than 1 hour, position: WFS000511, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# WiXXiaCs, MyrreXX has less than 10 hours between shifts but greater than 1 hour, position: WFS000511, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# WiXXiaCs, MyrreXX has less than 10 hours between shifts but greater than 1 hour, position: WFS000511, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# WiXXiaCs, MyrreXX has less than 10 hours between shifts but greater than 1 hour, position: WFS000511, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# WiXXiaCs, MyrreXX has less than 10 hours between shifts but greater than 1 hour, position: WFS000511, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# WiXXiaCs, MyrreXX has less than 10 hours between shifts but greater than 1 hour, position: WFS000511, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# WiXXiaCs, MyrreXX has less than 10 hours between shifts but greater than 1 hour, position: WFS000511, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# WiXXiaCs, MyrreXX has less than 10 hours between shifts but greater than 1 hour, position: WFS000511, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# WiXXiaCs, MyrreXX has less than 10 hours between shifts but greater than 1 hour, position: WFS000511, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# Skipping row due to unexpected 'Timecard Hours (as Time)' format: nan
# XEpez WAWez, XAis has less than 10 hours between shifts but greater than 1 hour, position: WFS000522, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# XEpez WAWez, XAis has less than 10 hours between shifts but greater than 1 hour, position: WFS000522, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# XEpez WAWez, XAis has less than 10 hours between shifts but greater than 1 hour, position: WFS000522, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# XEpez WAWez, XAis has less than 10 hours between shifts but greater than 1 hour, position: WFS000522, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# XEpez WAWez, XAis has less than 10 hours between shifts but greater than 1 hour, position: WFS000522, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# XEpez WAWez, XAis has less than 10 hours between shifts but greater than 1 hour, position: WFS000522, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# XEpez WAWez, XAis has less than 10 hours between shifts but greater than 1 hour, position: WFS000522, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# XEpez WAWez, XAis has less than 10 hours between shifts but greater than 1 hour, position: WFS000522, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# XariEs XaWdaverde, XAis ErWesME has less than 10 hours between shifts but greater than 1 hour, position: WFS000572, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# XariEs XaWdaverde, XAis ErWesME has less than 10 hours between shifts but greater than 1 hour, position: WFS000572, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# XariEs XaWdaverde, XAis ErWesME has less than 10 hours between shifts but greater than 1 hour, position: WFS000572, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# XariEs XaWdaverde, XAis ErWesME has less than 10 hours between shifts but greater than 1 hour, position: WFS000572, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# XariEs XaWdaverde, XAis ErWesME has less than 10 hours between shifts but greater than 1 hour, position: WFS000572, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# XariEs XaWdaverde, XAis ErWesME has less than 10 hours between shifts but greater than 1 hour, position: WFS000572, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# XariEs XaWdaverde, XAis ErWesME has less than 10 hours between shifts but greater than 1 hour, position: WFS000572, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# XariEs XaWdaverde, XAis ErWesME has less than 10 hours between shifts but greater than 1 hour, position: WFS000572, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# XariEs XaWdaverde, XAis ErWesME has less than 10 hours between shifts but greater than 1 hour, position: WFS000572, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# XariEs, Cesar GiEvaWWi has less than 10 hours between shifts but greater than 1 hour, position: WFS000587, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# XariEs, Cesar GiEvaWWi has less than 10 hours between shifts but greater than 1 hour, position: WFS000587, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# XariEs, Cesar GiEvaWWi has less than 10 hours between shifts but greater than 1 hour, position: WFS000587, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# XariEs, Cesar GiEvaWWi has less than 10 hours between shifts but greater than 1 hour, position: WFS000587, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# XariEs, Cesar GiEvaWWi has less than 10 hours between shifts but greater than 1 hour, position: WFS000587, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# XariEs, Cesar GiEvaWWi has less than 10 hours between shifts but greater than 1 hour, position: WFS000587, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# XariEs, Cesar GiEvaWWi has less than 10 hours between shifts but greater than 1 hour, position: WFS000587, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# XariEs, Cesar GiEvaWWi has less than 10 hours between shifts but greater than 1 hour, position: WFS000587, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# XariEs, Cesar GiEvaWWi has less than 10 hours between shifts but greater than 1 hour, position: WFS000587, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# XariEs, Cesar GiEvaWWi has less than 10 hours between shifts but greater than 1 hour, position: WFS000587, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# Xee, XaCar has less than 10 hours between shifts but greater than 1 hour, position: WFS000200, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# Xee, XaCar has less than 10 hours between shifts but greater than 1 hour, position: WFS000200, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# Xee, XaCar has less than 10 hours between shifts but greater than 1 hour, position: WFS000200, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# Xee, XaCar has less than 10 hours between shifts but greater than 1 hour, position: WFS000200, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# Xee, XaCar has less than 10 hours between shifts but greater than 1 hour, position: WFS000200, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# Xee, XaCar has less than 10 hours between shifts but greater than 1 hour, position: WFS000200, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# Xee, XaCar has less than 10 hours between shifts but greater than 1 hour, position: WFS000200, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# Xee, XaCar has less than 10 hours between shifts but greater than 1 hour, position: WFS000200, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# Xee, XaCar has less than 10 hours between shifts but greater than 1 hour, position: WFS000200, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# Xee, XaCar has less than 10 hours between shifts but greater than 1 hour, position: WFS000200, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# Xee, XaCar has less than 10 hours between shifts but greater than 1 hour, position: WFS000200, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# Xee, XaCar has less than 10 hours between shifts but greater than 1 hour, position: WFS000200, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# XiWW, JAsMiW has less than 10 hours between shifts but greater than 1 hour, position: WFS000462, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# XiWW, JAsMiW has less than 10 hours between shifts but greater than 1 hour, position: WFS000462, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# XiWW, JAsMiW has less than 10 hours between shifts but greater than 1 hour, position: WFS000462, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# XiWW, JAsMiW has less than 10 hours between shifts but greater than 1 hour, position: WFS000462, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# XiWW, JAsMiW has less than 10 hours between shifts but greater than 1 hour, position: WFS000462, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# XiWW, JAsMiW has less than 10 hours between shifts but greater than 1 hour, position: WFS000462, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# XiWW, JAsMiW has less than 10 hours between shifts but greater than 1 hour, position: WFS000462, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# ZaCEra, CigAeX has less than 10 hours between shifts but greater than 1 hour, position: WFS000499, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# ZaCEra, CigAeX has less than 10 hours between shifts but greater than 1 hour, position: WFS000499, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# ZaCEra, CigAeX has less than 10 hours between shifts but greater than 1 hour, position: WFS000499, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# ZaCEra, CigAeX has less than 10 hours between shifts but greater than 1 hour, position: WFS000499, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# ZaCEra, CigAeX has less than 10 hours between shifts but greater than 1 hour, position: WFS000499, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# ZaCEra, CigAeX has less than 10 hours between shifts but greater than 1 hour, position: WFS000499, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# ZaCEra, CigAeX has less than 10 hours between shifts but greater than 1 hour, position: WFS000499, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# ZaCEra, CigAeX has less than 10 hours between shifts but greater than 1 hour, position: WFS000499, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# ZaCEra, CigAeX has less than 10 hours between shifts but greater than 1 hour, position: WFS000499, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# ZaCEra, Edward has less than 10 hours between shifts but greater than 1 hour, position: WFS000477, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# ZaCEra, Edward has less than 10 hours between shifts but greater than 1 hour, position: WFS000477, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# ZaCEra, Edward has less than 10 hours between shifts but greater than 1 hour, position: WFS000477, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# ZaCEra, Edward has less than 10 hours between shifts but greater than 1 hour, position: WFS000477, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00
# ZaCEra, Edward has less than 10 hours between shifts but greater than 1 hour, position: WFS000477, Pay Cycle Start Date: 2023-09-10 00:00:00, Pay Scale End Date: 2023-09-23 00:00:00

# %%
import pandas as pd
from datetime import timedelta
import sys

def analyze_timecard(file_path):
    # Load the data from the Excel file
    df = pd.read_excel(file_path)

    # Convert relevant columns to datetime format
    df['Time'] = pd.to_datetime(df['Time'])
    df['Time Out'] = pd.to_datetime(df['Time Out'])
    df['Pay Cycle Start Date'] = pd.to_datetime(df['Pay Cycle Start Date'])
    df['Pay Cycle End Date'] = pd.to_datetime(df['Pay Cycle End Date'])

    # Sort the DataFrame by 'Employee Name' and 'Time'
    df.sort_values(by=['Employee Name', 'Time'], inplace=True)

    # Function to check consecutive days worked
    def consecutive_days(row):
        consecutive_days_count = 1
        prev_date = row['Time']
        
        for _, next_row in df[df['Employee Name'] == row['Employee Name']].iterrows():
            if (next_row['Time'] - prev_date).days == 1:
                consecutive_days_count += 1
                prev_date = next_row['Time']
            else:
                break
        
        return consecutive_days_count

    # Redirecting console output to a file
    original_stdout = sys.stdout
    with open('output.txt', 'w') as f:
        sys.stdout = f

        # Iterate over the records and print the required information
        for _, row in df.iterrows():
            consecutive_days_count = consecutive_days(row)

            if consecutive_days_count == 7:
                print(f"{row['Employee Name']} worked for 7 consecutive days, position: {row['Position ID']}, Pay Cycle Start Date: {row['Pay Cycle Start Date']}, Pay Scale End Date: {row['Pay Cycle End Date']}")

            # Check if there are previous records for the same employee
            previous_records = df[(df['Employee Name'] == row['Employee Name']) & (df['Time'] < row['Time'])]
            if not previous_records.empty:
                # Calculate time_between_shifts
                time_between_shifts = (row['Time'] - previous_records.iloc[-1]['Time']).seconds / 3600

                if 1 < time_between_shifts < 10:
                    print(f"{row['Employee Name']} has less than 10 hours between shifts but greater than 1 hour, position: {row['Position ID']}, Pay Cycle Start Date: {row['Pay Cycle Start Date']}, Pay Scale End Date: {row['Pay Cycle End Date']}")

            # Convert 'Timecard Hours (as Time)' to timedelta
            timecard_hours_str = str(row['Timecard Hours (as Time)'])
            try:
                if ':' in timecard_hours_str:
                    hours, minutes = map(int, timecard_hours_str.split(':'))
                    timecard_hours = timedelta(hours=hours, minutes=minutes)

                    if timecard_hours.total_seconds() / 3600 > 14:
                        print(f"{row['Employee Name']} worked for more than 14 hours in a single shift, position: {row['Position ID']}, Pay Cycle Start Date: {row['Pay Cycle Start Date']}, Pay Scale End Date: {row['Pay Cycle End Date']}")
                else:
                    print(f"Skipping row due to unexpected 'Timecard Hours (as Time)' format: {timecard_hours_str}")
            except (ValueError, TypeError):
                # Handle cases where the format is unexpected or cannot be converted to timedelta
                print(f"Skipping row due to unexpected 'Timecard Hours (as Time)' format: {timecard_hours_str}")

    # Resetting console output to the original
    sys.stdout = original_stdout

if __name__ == "__main__":
    # Specify the path to your Excel file
    file_path = 'F:/Assingment/Assignment_Timecard.XLSX'

    # Run the analysis
    analyze_timecard(file_path)
